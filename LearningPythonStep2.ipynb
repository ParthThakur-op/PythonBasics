# %% [markdown]
# # Strings
#
# - strings are *ordered* sequence of characters
# - strings are *immutable*
#   - i.e. cannot be modified after being created

# %%
# string defined with single quotes
name_one = 'Python'

print(name_one)

# string defined with double quotes
name_two = "Python"

print(name_two)

# string defined with triple single quotes
name_three = '''This is line 1.
This is line 2.
This is line 3.'''
print(name_three)

# string defined with double quotes inside the single quotes (use opposite quotation)
name_four = 'Hello, "AI students"'
print(name_four)

name_five = "Hello, 'AI students'"
print(name_five)
# Out:
# Python
# Python
# This is line 1.
# This is line 2.
# This is line 3.
# Hello, "AI students"
# Hello, 'AI students'

# %% [markdown]
# ### Excercise : 1
#
# Make two strings ,`first_name` and `last_name` and add your name in those strings and then print them

# %%
first_name = "Parth" 
last_name = "Thakur" 

full_name = first_name + " " + last_name

print(full_name)
# Out:
# Parth Thakur

# %% [markdown]
# ### String Immutability Test

# %%
# define string
s = "hello"

# attempt assigment
s[0]  = 'y' #throws error - hence strings are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 # define string
#       2 s = "hello"
#       3
#       4 # attempt assigment
# ----> 5 s[0]  = 'y' #throws error - hence strings are immutable
#
# TypeError: 'str' object does not support item assignment

# %%
# however, rebinding works
# reassigning s with 'y' concatenated with 'ello' extracted from s
s = 'y' + s[1:len(s)] # y + ello

print(s)
# Out:
# yello

# %% [markdown]
# This is called string slicing.
# s
#
# The variable containing:
#
# "hello"
#
# [ ]
#
# Square brackets are used to access or slice characters.
#
# 1:
#
# Means:
#
# Start from index 1.
#
# h e l l o
# 0 1 2 3 4
#
# Index 1 is
#
# e
#
# len(s)
#
# len() means length.
#
# len("hello")
#
# returns
#
# 5
#
# So
#
# s[1:len(s)]
#
# becomes
#
# s[1:5]
#
# which means
#
# Start at index 1
# Stop before index 5
#
# Python takes
#
# Index 1 → e
# Index 2 → l
# Index 3 → l
# Index 4 → o
#
# Result:
#
# "ello"
# Part 3
# 'y' + "ello"
#
# The + joins (concatenates) strings.
#
# Result:
#
# "yello"

# %% [markdown]
# #### Now that we know strings are immutable
#
# ### Excercise : 2
#
# In the above string where we are replacing the `h` of `hello` to `y` ,write a command which adds `w` at the end of `yello` to make `yellow` !

# %%
s = "hello"

s = "y" + s[1:len(s)] + "w"

print(s)
# Out:
# yellow

# %% [markdown]
# ### String Concatenation

# %%
first_name = "Parth"
last_name = "Thakur"
full_name = first_name  + ' ' + last_name
print(full_name)
# Out:
# Parth Thakur

# %% [markdown]
# ### Excercise : 3
#
# In **Excercise : 1 ** we had created two strings ,`first_name` and `last_name` , write a command to print these two variables in the same line by concatenating them !

# %%
first_name = "Parth"
last_name = "Thakur"

print(first_name + " " + last_name) # this is called concatinating / adding
# Out:
# Parth Thakur

# %% [markdown]
# ### String Multiplication

# %%
name = 'Sybau'
print(name)
name_thrice = name * 3
print(name_thrice)
print(name*4)
print(name*10)
# Out:
# Sybau
# SybauSybauSybau
# SybauSybauSybauSybau
# SybauSybauSybauSybauSybauSybauSybauSybauSybauSybau

# %% [markdown]
# #### Printing the same string can be time consuming !
#
# ### Excercise : 4
#
# Print your `first_name` six times using string multiplication, do you find it easier compared to writting 6 individual prints?

# %%
first_name = "Parth Thakur. "

print(first_name)
first_name_6times = first_name*6
print(first_name_6times)
# Out:
# Parth Thakur.
# Parth Thakur. Parth Thakur. Parth Thakur. Parth Thakur. Parth Thakur. Parth Thakur.

# %% [markdown]
# ### String Length

# %%
len(first_name_6times)
# Out:
# 84

# %%
len(first_name)
# Out:
# 14

# %% [markdown]
# ## String Methods

# %%
name = "parth thakur"

# %%
print(name)
# Out:
# parth thakur

# %%
name.upper()
# Out:
# 'PARTH THAKUR'

# %%
name
# Out:
# 'parth thakur'

# %%
name = "PARTH THAKUR"
name
# Out:
# 'PARTH THAKUR'

# %%
name.lower()
# Out:
# 'parth thakur'

# %%
name = name.upper() #over writing the variable

# %%
name
# Out:
# 'PARTH THAKUR'

# %%
sent = "what a wonderful day"

print(sent)

sent.capitalize()
# Out:
# what a wonderful day
# 'What a wonderful day'

# %%
movie = 'spider-man brand new day'

movie
# Out:
# 'spider-man brand new day'

# %%
movie.title()
# Out:
# 'Spider-Man Brand New Day'

# %%
movie.split()
# Out:
# ['spider-man', 'brand', 'new', 'day']

# %%
movie_title_list = ['spider-man', 'brand', 'new', 'day']
movie_title_list
# Out:
# ['spider-man', 'brand', 'new', 'day']

# %%
movieTitle = ' '.join(movie_title_list)
movieTitle
# Out:
# 'spider-man brand new day'

# %%
movieTitle = '-'.join(movie_title_list)
movieTitle
# Out:
# 'spider-man-brand-new-day'

# %%
movieTitle = ','.join(movie_title_list)
movieTitle
# Out:
# 'spider-man,brand,new,day'

# %%
email = 'parththakur656@gmail.com'
print(email)
# Out:
# parththakur656@gmail.com

# %%
email.split('@') #split on the basis of @
# Out:
# ['parththakur656', 'gmail.com']

# %% [markdown]
# ### String Indexing
#
# - in Python,
#   - indexing of sequences starts from 0
# - string is a text sequence,
#   - so indexing for strings starts from 0
#
# ![string indexing](https://i.imgur.com/eYQmNiWl.jpg "String Indexing")

# %%
s = 'abc'
# define a string
s = "abc"
    #012
# indexing starts from 0 in Python

# use square brackets and the index number to access data
print(s[0]) # output: a
print(s[1]) # output: b
print(s[2]) # output: c

print(s[-1]) # output: c
print(s[-2]) # output: b
print(s[-3]) # output: a

print(s[3]) # output: index error
# Out:
# a
# b
# c
# c
# b
# a
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[40], line 16
#      12 print(s[-1]) # output: c
#      13 print(s[-2]) # output: b
#      14 print(s[-3]) # output: a
#      15
# ---> 16 print(s[3]) # output: index error
#
# IndexError: string index out of range

# %% [markdown]
# ### Excercise :  5
#
# Create a variable with the string value `This is one sentence!`, print out the index of the `o`

# %%
string = "This is one sentence!"
string[0]
# Out:
# 'T'

# %%
string = "abcdefghijklmnopqrstuvwxyz"
len(string)
# Out:
# 26

# %%
string[3:10:1]
# Out:
# 'defghij'

# %%
string[0:26:2]
# Out:
# 'acegikmoqsuwy'

# %%
sent = 'This is one sentence!'
sent.index('o')
# Out:
# 8

# %%
sent[8]
# Out:
# 'o'

# %%
string[:5]
# Out:
# 'abcde'

# %%
string[2:]
# Out:
# 'cdefghijklmnopqrstuvwxyz'

# %%
string[::2]
# Out:
# 'acegikmoqsuwy'

# %%
string[::-2]
# Out:
# 'zxvtrpnljhfdb'

# %%
string[3:-10:1]
# Out:
# 'defghijklmnop'

# %%
string[3:10:-1]
# Out:
# ''

# %%
s = 'abcdefgh'
s[6:2:-1]
# Out:
# 'gfed'

# %% [markdown]
# ### Excercise : 6
#
# From the variable you created in **Excercise : 5** by using string slicing, print out `one`

# %%
sent = 'This is one sentence!'
sent[8:11]
# Out:
# 'one'

# %%
sent[5]
# Out:
# 'i'

# %%
sent[4]
# Out:
# ' '

# %%
s = 'hello'

s = 'y' + s[1:5] + 'w'

# %%
s
# Out:
# 'yellow'

# %% [markdown]
# # List
#
# - lists are ordered sequences of objects
#   - they are mutable

# %%
li = [1,2,4.5,'orange',0]
li
# Out:
# [1, 2, 4.5, 'orange', 0]

# %%
li[0]
# Out:
# 1

# %%
li[-2]
# Out:
# 'orange'

# %%
li[1:]
# Out:
# [2, 4.5, 'orange', 0]

# %%
li[1:4]
# Out:
# [2, 4.5, 'orange']

# %%
li[::2]
# Out:
# [1, 4.5, 0]

# %%
li[::-2] # all of these were list slicing
# Out:
# [0, 4.5, 1]

# %% [markdown]
# #### Let's build our own lists now
#
# ### Excercise : 7
#
# Create grocery list in form of a python script ,you can add items such as `banana`,`milk` etc !

# %%
list = ['banana','milk','mad-angles']
list
# Out:
# ['banana', 'milk', 'mad-angles']

# %% [markdown]
# #### Let's take out a element from our list
#
# ### Excercise : 8
#
# From the grocery we just created in the above section, using list slicing print out the `banana` element

# %%
list = ['banana','milk','mad-angles']
print(list[0])
# Out:
# banana

# %% [markdown]
# # Nested list

# %%
nested_list = [[1,2,3],['a','b','c'],['true','true','true']]
nested_list
# Out:
# [[1, 2, 3], ['a', 'b', 'c'], ['true', 'true', 'true']]

# %%
len(nested_list)
# Out:
# 3

# %%
nested_list[0]
# Out:
# [1, 2, 3]

# %%
nested_list[0][0]
# Out:
# 1

# %%
nested_list[0][1]
# Out:
# 2

# %%
nested_list[1][1]
# Out:
# 'b'

# %%
nested_list[2][0]
# Out:
# 'true'

# %%
print(nested_list[0][0],nested_list[1][0],nested_list[2][0])
# Out:
# 1 a true

# %% [markdown]
# ### Excercise : 9
#
# Make a nested list of various your favorite animals ,colours and songs and then print it

# %%
list =[['Tiger','Lion','cat'],['red','black','purple'],['noir','passionfruit','poster boy']]
print(list)
# Out:
# [['Tiger', 'Lion', 'cat'], ['red', 'black', 'purple'], ['noir', 'passionfruit', 'poster boy']]

# %% [markdown]
# ##### List Mutability Test

# %%
list = ['apple','orange','mango']

print(list)

list[0] = 'peach'

print(list)
# Out:
# ['apple', 'orange', 'mango']
# ['peach', 'orange', 'mango']

# %%
# define list
new_list = [3,7,20,'@','GFG', 'makes learning fun!']

# try changing content in list
new_list[2] = 'one' # accepts change

# check list
print(new_list)
# Out:
# [3, 7, 'one', '@', 'GFG', 'makes learning fun!']

# %% [markdown]
# ##### Append to List
#
# - append can add *only one* element at the end of a list at a time

# %%
# define a list
new_list = [3,7,20,'@','GFG', 'makes learning fun!']

# print new list
print(new_list)

# append 'wohoo' to new_list
new_list.append('wohoo!')

# check apended value
print(new_list)
# Out:
# [3, 7, 20, '@', 'GFG', 'makes learning fun!']
# [3, 7, 20, '@', 'GFG', 'makes learning fun!', 'wohoo!']

# %% [markdown]
# ##### Extend List
#
# - used to add multiple elements at the end of the list

# %%
# define a list
new_list = [3,7,20,'@','GFG', 'makes learning fun!']

# print new list
print(new_list)

# extend new_list with multiple elements in an array
new_list.extend(["Let's", "do", "this","!"])
# NOTE: multiple elements have to be input in array

print(new_list)
# Out:
# [3, 7, 20, '@', 'GFG', 'makes learning fun!']
# [3, 7, 20, '@', 'GFG', 'makes learning fun!', "Let's", 'do', 'this', '!']

# %% [markdown]
# ##### Insert to List
#
# - can add an element at a given position in the list
# - can add only one element at a time
# - two arguments:
#   - first argument specifies the position
#   - second argument specifies the element to be inserted

# %%
# define list
new_list = [3,7,20,'@','TECH I.S.', 'makes learning fun!']

# insert element 'Chocolate' at spot 3 in new_list
new_list.insert(3,'Chocolate')

# check insertion
print(new_list)
# Out:
# [3, 7, 20, 'Chocolate', '@', 'TECH I.S.', 'makes learning fun!']

# %% [markdown]
# ### Excercise : 10
#
# In the list that you created in **Excercise : 5** append `almonds` into it !

# %%
new_list = [3,7,20,'@','TECH I.S.', 'makes learning fun!']
new_list.append('almond')
print(new_list)
# Out:
# [3, 7, 20, '@', 'TECH I.S.', 'makes learning fun!', 'almond']

# %%
string = "what is your name"

string = string[0:] + ' ?'

# %%
string
# Out:
# 'what is your name ?'

# %% [markdown]
# ##### Remove from List
#
# - used to remove an element from the list
#   - in the case of multiple occurrences, only the first is removed

# %%
# define list
new_list = [3,7,20,'@','TECH I.S.', 'makes learning fun!']

# remove 20 from new_list
new_list.remove('@')

# check removal
print(new_list)
# Out:
# [3, 7, 20, 'TECH I.S.', 'makes learning fun!']

# %% [markdown]
# ### Excercise : 11
#
# Perform a removal operation `almonds` from your list which you just added to

# %%
new_list = [3,7,20,'@','TECH I.S.', 'makes learning fun!']
new_list.append('almond')
print(new_list)

new_list.remove(7)
new_list.remove('almond')

print(new_list)
# Out:
# [3, 7, 20, '@', 'TECH I.S.', 'makes learning fun!', 'almond']
# [3, 20, '@', 'TECH I.S.', 'makes learning fun!']

# %% [markdown]
# ##### Pop from List
#
# - can remove an element from any position in the list
#   - removes index item
# - element is not specified like in `remove()` method, only the index position

# %%
# define list
new_list = [3,7,20,'@','TECH I.S.', 'makes learning fun!']

# pop spot 2 from list
new_list.pop(3) # this 3 is index not the element in the list so it will remove 3rd index element

# check list
print(new_list)
# Out:
# [3, 7, 20, 'TECH I.S.', 'makes learning fun!']

# %%
new_list.pop() #Remove the last item from the list. Return the removed item. Since you didn't specify an index, Python removes the last element.
print(new_list)
# Out:
# [3, 7, 20, 'TECH I.S.']

# %% [markdown]
# ##### `remove()` vs. `pop()`
#
# |`remove()`|`pop()`|
# |---|---|
# |removes element by identification|removes by index|
# |`new_list.remove(element_to_remove)`|`new_list.pop(index_number_to_remove)`|

# %% [markdown]
# ##### Reverse a List
#
# - used to reverse the elements of a list
#
# - can be done in two ways
#   - modify the original list
#   - without modifying the original list

# %%
# define list
new_list = [3,7,20,'@','TECH I.S.', 'makes learning fun!']

# without modifying the original list
print(new_list[::-1])
print(new_list) # unmodified original list ( original list is not change)

# modify the original list
new_list.reverse() # modify original list
print(new_list)

new_list.reverse() # modify original list
print(new_list)
# Out:
# ['makes learning fun!', 'TECH I.S.', '@', 20, 7, 3]
# [3, 7, 20, '@', 'TECH I.S.', 'makes learning fun!']
# ['makes learning fun!', 'TECH I.S.', '@', 20, 7, 3]
# [3, 7, 20, '@', 'TECH I.S.', 'makes learning fun!']

# %%
del(new_list[0])
new_list
# Out:
# [7, 20, '@', 'TECH I.S.', 'makes learning fun!']

# %%
del(new_list)
new_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 del(new_list)
# ----> 2 new_list
#
# NameError: name 'new_list' is not defined

# %%
len(new_list)
# Out:
# 6

# %%
b = [2,3,2,3,4,5,6,4,5,7]
print(b)
c = set(b)
print(c)
b = list(c)
print(b)
# Out:
# [2, 3, 2, 3, 4, 5, 6, 4, 5, 7]
# {2, 3, 4, 5, 6, 7}
# [2, 3, 4, 5, 6, 7]

# %%
b.remove(4)

# %%
b
# Out:
# [2, 3, 5, 6, 7]

# %%
b.insert(2,4)

# %%
b
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
b.pop(2)
b
# Out:
# [2, 3, 5, 6, 7]

# %%
b
# Out:
# [2, 3, 5, 6, 7]

# %%
b.clear()
b
# Out:
# []

# %%
li = [4,5,2,4,2,24,7,8,2,7,8] 
print(li)
# Out:
# [4, 5, 2, 4, 2, 24, 7, 8, 2, 7, 8]

# %%
e = set(li)
li = list(e)
print(li)

li.sort() #this will do ascending order
print(li)
# Out:
# [2, 4, 5, 7, 8, 24]
# [2, 4, 5, 7, 8, 24]

# %%
li
# Out:
# [2, 4, 5, 7, 8, 24]

# %%
li.sort(reverse=True) # descending order
print(li)
# Out:
# [24, 8, 7, 5, 4, 2]

# %%
type(li)
# Out:
# list

# %%
li = [2,4,1,3,7,8]

sorted_list = sorted(li)

print(li)
print(sorted_list)

sorted_list = sorted(li,reverse=True)

print(sorted_list)
# Out:
# [2, 4, 1, 3, 7, 8]
# [1, 2, 3, 4, 7, 8]
# [8, 7, 4, 3, 2, 1]

# %%
li.sort()
li
# Out:
# [1, 2, 3, 4, 7, 8]

# %%
li.sort(reverse=True)

# %%
li
# Out:
# [8, 7, 4, 3, 2, 1]

# %% [markdown]
# ##### Min & Max Values of a List
#
# - min() returns the *minimum* value in the list
# - max() returns the *maximum* value in the list
#
# - NOTE: both methods accept only *homogeneous* lists
#   - i.e. list having elements of similar data type

# %%
# define list
new_list = [8,12,7,10,52,33,21,99]

# check min and max of new_list
print(min(new_list))
print(max(new_list))

# define list
new_list = ['x','10','99','t','%','-']

# check min and max of new_list
print(min(new_list))
print(max(new_list))
# Out:
# 7
# 99
# %
# x

# %% [markdown]
# ##### Count of an Element in a List
#
# - returns the number of occurrences of a given element in the list

# %%
# define list
new_list = [8,12,7,10,7,33,21,7]

# count the number of occurences of 7
print(new_list.count(7))

# count the number of occurences of 10
print(new_list.count(10))
print(new_list.count(9))
# Out:
# 3
# 1
# 0

# %% [markdown]
# # Excercise : 13
# * On the list on which we performed `pop` run the `len` function and make a note of how many items we have !

# %%
# define list
new_list = [3,7,20,'@','TECH I.S.', 'makes learning fun!']

# pop spot 2 from list
new_list.pop(3) # this 3 is index not the element in the list so it will remove 3rd index element

# check list
print(new_list) 
len(new_list)
# Out:
# [3, 7, 20, 'TECH I.S.', 'makes learning fun!']
# 5

# %% [markdown]
# #### Concatenate Lists
# * used to merge two lists and return a single list

# %%
# define two lists
list_first = ['three','hundred']
print(list_first)

list_second = ['words','in','a','paragraph']
print(list_second)

# concatenate lists
list_combined = list_first + list_second
print(list_combined)
# Out:
# ['three', 'hundred']
# ['words', 'in', 'a', 'paragraph']
# ['three', 'hundred', 'words', 'in', 'a', 'paragraph']

# %% [markdown]
# #### multiply list

# %%
# define list
new_list = [3,7,20,'@','TECH I.S.', 'makes learning fun!']

# multiply list
print(new_list*2)
print(new_list*3)
# Out:
# [3, 7, 20, '@', 'TECH I.S.', 'makes learning fun!', 3, 7, 20, '@', 'TECH I.S.', 'makes learning fun!']
# [3, 7, 20, '@', 'TECH I.S.', 'makes learning fun!', 3, 7, 20, '@', 'TECH I.S.', 'makes learning fun!', 3, 7, 20, '@', 'TECH I.S.', 'makes learning fun!']

# %% [markdown]
# ##### Location of the First Occurence
#
#  - `index()` method returns the position of the first occurrence of the given element
#
#
#  - optional parameters:
#   - the begin index and
#   - the end index
#
# - when optional arguments are given:
#   - the element is searched only in the sub-list bound by the begin and end indices
#
# - when not supplied,
#   - the element is searched in the whole list

# %%
# define list
new_list = [3,7,20,'@','GFG', 'makes learning fun!']

# search index of 'TECH I.S.'
print(new_list.index('GFG'))

# search '@' with optional arguments
print(new_list.index('@',1,4)) # here 1 is index to start and 4th index where it stops searching
# Out:
# 4
# 3

# %%
li = ['a','b','c','b','d','e']
print(li.index('b'))
li.index('b',2,len(li)) # index(element,start,stop)
# Out:
# 1
# 3

# %% [markdown]
# # Tuples
#
# - tuples are ordered sequences of objects
#   - they are immutable
#   - i.e. their content cannot be changed after creation

# %%
# create a new tuple - without specifying brackets
new_tuple_one = 1,2,3,4,'parth'

# print tuple
print(new_tuple_one)

#--------------------------------------------------------
# create a new tuple - with brackets
new_tuple_two = (5,6,"python",8)

# print tuple
print(new_tuple_two)

#--------------------------------------------------------
# create empty tuple
empty_tuple = ()

# check empty tuple
print(empty_tuple)

#--------------------------------------------------------
# create tuple using Constructor
new_tuple_three = tuple(("apple","banana","cherry"))

# check empty tuple
print(new_tuple_three)

#--------------------------------------------------------
# single element tuples
new_tuple_wrong = ("apple") # wrong single element tuple
print(type(new_tuple_wrong))  # outputs string
print(new_tuple_wrong)

new_tuple_right = ("apple",) # correct single element tuple
print(type(new_tuple_right)) # outputs tuple
print(new_tuple_right)
# Out:
# (1, 2, 3, 4, 'parth')
# (5, 6, 'python', 8)
# ()
# ('apple', 'banana', 'cherry')
# <class 'str'>
# apple
# <class 'tuple'>
# ('apple',)

# %% [markdown]
# ##### Indexing in Tuples
#
# - indexing in tuples works just like strings

# %%
# define a new tuple
new_tuple = "apple","orange","banana","berry","mango"

print(new_tuple[0]) # zeroth element
print(new_tuple[1]) # first element
print(new_tuple[2]) # second element
print(new_tuple[3]) # third element
print(new_tuple[4]) # fourth element

print(new_tuple[-1]) #last element
print(new_tuple[-2]) #last but one element
print(new_tuple[-3]) #last but two element
print(new_tuple[-4]) #last but three element

print(new_tuple[5]) # throws error - no fifth element
# Out:
# apple
# orange
# banana
# berry
# mango
# mango
# berry
# banana
# orange
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 15
#      11 print(new_tuple[-2]) #last but one element
#      12 print(new_tuple[-3]) #last but two element
#      13 print(new_tuple[-4]) #last but three element
#      14
# ---> 15 print(new_tuple[5]) # throws error - no fifth element
#
# IndexError: tuple index out of range

# %% [markdown]
# ##### Tuple Immutability Test

# %%
# define tuple
new_tuple = (1,7,'$', 'Summers', 'Winters' )

# try changing tuple content
new_tuple[4] = 'Spring' # throws error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 5
#       1 # define tuple
#       2 new_tuple = (1,7,'$', 'Summers', 'Winters' )
#       3
#       4 # try changing tuple content
# ----> 5 new_tuple[4] = 'Spring' # throws error
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ##### Concatenation of Tuples
#
# -  tuples are immutable, hence the data stored in a tuple cannot be edited
# - but it's definitely possible to merge two tuples to create a new tuple

# %%
# define two new tuple
new_tuple_one = 9,5,6,4,2,1
new_tuple_two = 'a',5,7,6,3,1

print(new_tuple_one)
print(new_tuple_two)

# add a new element
merged_tuple = new_tuple_one + new_tuple_two

# check merged tuple
print(merged_tuple)
# Out:
# (9, 5, 6, 4, 2, 1)
# ('a', 5, 7, 6, 3, 1)
# (9, 5, 6, 4, 2, 1, 'a', 5, 7, 6, 3, 1)

# %% [markdown]
# ##### Multiplication (Duplication) of Tuples
#
# - duplicates the content of a tuple, the specified number of times

# %%
# define a tuple
new_tuple = 'a',5,7,6,3,1

print(new_tuple)

# multiply and print result
print(new_tuple*2)
print(new_tuple*3)
# Out:
# ('a', 5, 7, 6, 3, 1)
# ('a', 5, 7, 6, 3, 1, 'a', 5, 7, 6, 3, 1)
# ('a', 5, 7, 6, 3, 1, 'a', 5, 7, 6, 3, 1, 'a', 5, 7, 6, 3, 1)

# %% [markdown]
# ##### Length of a Tuple

# %%
# define a tuple
new_tuple = 'a',5,7,6,3,1

len(new_tuple)
# Out:
# 6

# %% [markdown]
# ##### Min & Max Values of a Tuple
#
# - min() returns the minimum value in the tuple
# - max() returns the maximum value in the tuple
#
# - both methods accept only homogeneous tuples
#   - i.e. tuples having elements of similar data type

# %%
# define tuple
new_tuple = 8,12,7,10,52,33,21,99

# check min and max of new_tuple
print(min(new_tuple))
print(max(new_tuple))

# define list
new_tuple = 'x','10','99','twenty','%$','--',

# check min and max of new_list
print(min(new_tuple))
print(max(new_tuple))
# Out:
# 7
# 99
# %$
# x

# %% [markdown]
# ##### Count of an Element in a Tuple

# %%
# define a tuple
new_tuple = 5,3,6,3,1,3,2,3

# count the number of 3s in the tuple
print(new_tuple.count(3))
# Out:
# 4

# %% [markdown]
# ##### Location of First Occurence

# %%
# define a tuple
new_tuple = 5,6,3,1,3,2,3

# find the index location of the first occurence of 3
print(new_tuple.index(3))
# Out:
# 2

# %% [markdown]
# ##### Delete a Tuple
#
# - you cannot remove the elements in a tuple
# - but you can delete an entire tuple

# %%
# define a tuple
new_tuple = 5,3,6,3,1,3,2,3

# check tuple
print(new_tuple)

# delete the tuple
del(new_tuple)

# check deletion
print(new_tuple) # will throw an error becasue tuple doesnt exists
# Out:
# (5, 3, 6, 3, 1, 3, 2, 3)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 11
#       7 # delete the tuple
#       8 del(new_tuple)
#       9
#      10 # check deletion
# ---> 11 print(new_tuple) # will throw an error becasue tuple doesnt exists
#
# NameError: name 'new_tuple' is not defined
